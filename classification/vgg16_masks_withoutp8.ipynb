# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import random

from keras import layers
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras import models
from keras import optimizers
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from keras import applications

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

import glob
import os
from datetime import datetime
# Out:
# Using TensorFlow backend.

# %%
img_src_folder = "lung-segmentation/uniq"
os.listdir(img_src_folder)
# Out:
# ['p17',
#  'p5',
#  'p7',
#  'multigif.py',
#  'p13',
#  'p11',
#  'p16',
#  'p6',
#  'p8',
#  'p15',
#  'p14',
#  'p1',
#  'p4',
#  'p18',
#  'p3',
#  'p19',
#  'p12',
#  'p9',
#  'p10',
#  'p2',
#  'gifs.zip',
#  'p20']

# %%
#1-5: normal patients, 11-20: covid patients.
other_patients = []
covid_patients = []
for root, dirs, files in os.walk(img_src_folder):
    for d in dirs:
        if d[0] == 'p':
            num = int(d[1:])
            if num <= 10: other_patients.append(d)
            elif num >= 11: covid_patients.append(d)

# %%
sorted(other_patients)
# Out:
# ['p1', 'p10', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9']

# %%
sorted(covid_patients)
# Out:
# ['p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20']

# %%
now = datetime.now()
#defining the minimum number of patients of each class that will be in the test set.
test_patients_per_label = 0
#building the test set with the declared num of patients of each class
TEST_IMG_FOLDERS = sorted(other_patients)[0:test_patients_per_label]
TEST_IMG_FOLDERS = sorted(covid_patients)[0:test_patients_per_label]

#splitting the test data and the rest (training and validation)
if test_patients_per_label > 0:
    for n in range(test_patients_per_label):
        other_patients.pop(0)
        covid_patients.pop(0)
        
#defining the number of patients in training set
num_train_patients = int(0.8*min(len(other_patients), len(covid_patients)))
        
train_other_folders = sorted(other_patients)[0:num_train_patients]
train_label_1 = ['other' for i in range(len(train_other_folders))]

validation_other_folders = list(set(other_patients) - set(train_other_folders))
validation_label_1 = ['other' for i in range(len(validation_other_folders))]

train_covid_folders = sorted(covid_patients)[0:num_train_patients]
train_label_2 = ['covid' for i in range(len(train_covid_folders))]

validation_covid_folders = list(set(covid_patients) - set(train_covid_folders))
validation_label_2 = ['covid' for i in range(len(validation_covid_folders))]

#balancing validation set members for each label (other or covid)
label_1_size = len(validation_other_folders)
label_2_size = len(validation_covid_folders)
dif = label_1_size - label_2_size
if dif != 0:
    greater_label = validation_other_folders #supposing one label as having more elements
    if label_2_size > label_1_size:
        greater_label = validation_covid_folders
        dif = abs(dif)
    for n in range(dif): #deletes an random majoritary's label patient until labels are balanced
        index = random.randint(0, len(greater_label) - 1)
        TEST_IMG_FOLDERS.append(greater_label[index])
        greater_label.pop(index)

TRAIN_IMG_SRC_FOLDER = img_src_folder
VALIDATION_IMG_SRC_FOLDER = img_src_folder
TEST_IMG_SRC_FOLDER = img_src_folder

TRAIN_IMG_FOLDERS = dict(zip(train_other_folders, train_label_1))
TRAIN_IMG_FOLDERS.update(dict(zip(train_covid_folders, train_label_2)))

VALIDATION_IMG_FOLDERS = dict(zip(validation_other_folders, validation_label_1))
VALIDATION_IMG_FOLDERS.update(dict(zip(validation_covid_folders, validation_label_2)))

# %%
TRAIN_IMG_FOLDERS
# Out:
# {'p1': 'other',
#  'p10': 'other',
#  'p2': 'other',
#  'p3': 'other',
#  'p4': 'other',
#  'p5': 'other',
#  'p6': 'other',
#  'p7': 'other',
#  'p11': 'covid',
#  'p12': 'covid',
#  'p13': 'covid',
#  'p14': 'covid',
#  'p15': 'covid',
#  'p16': 'covid',
#  'p17': 'covid',
#  'p18': 'covid'}

# %%
VALIDATION_IMG_FOLDERS
# Out:
# {'p8': 'other', 'p9': 'other', 'p19': 'covid', 'p20': 'covid'}

# %%
TEST_IMG_FOLDERS
# Out:
# []

# %%
CLASSES = len(set([label for label in TRAIN_IMG_FOLDERS.values()]))
EXAM_SLICE = 200
EPOCHS = 15
width = 150
height = 150
print(CLASSES)
# Out:
# 2

# %%
dfs = []
train_images = {"id": [], "label": []}
validation_images = {"id": [], "label": []}

df_config = [
    (TRAIN_IMG_SRC_FOLDER, TRAIN_IMG_FOLDERS, train_images),
    (VALIDATION_IMG_SRC_FOLDER, VALIDATION_IMG_FOLDERS, validation_images)
]

def get_file_path(folder, search_filter=''):
    paths = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            path = os.path.join(root, file)
            if search_filter in path:
                paths.append(path)
    return paths

for (base, folder, dic) in df_config:
    for img_folder, img_label in folder.items():
        search_folder = "{}/{}".format(base, img_folder)
        imgs_filename = sorted(get_file_path(search_folder, search_filter = 'masks'))
        imgs_filename = imgs_filename[(len(imgs_filename)-EXAM_SLICE)//2:(len(imgs_filename)+EXAM_SLICE)//2]
        dic["id"].extend(imgs_filename)
        dic["label"].extend([img_label] * len(imgs_filename))
        
    dfs.append(pd.DataFrame(data=dic))

train_df, validation_df = dfs[0], dfs[1]

train_df.to_csv('train_df.csv', index=False)
validation_df.to_csv('validation_df.csv', index=False)

print("Train fold with {} images".format(len(train_df)))
print(train_df.groupby("label").label.count())
print()
print("Validation fold with {} images".format(len(validation_df)))
print(validation_df.groupby("label").label.count())
print("-" * 30)
# Out:
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------

# %% [markdown]
# Random Visualization of Training Data Samples

# %%
def get_side(img, side_type, side_size=5):
    height, width, channel=img.shape
    if side_type=="horizontal":
        return np.ones((height,side_size,  channel), dtype=np.float32)*255
        
    return np.ones((side_size, width,  channel), dtype=np.float32)*255

def show_gallery(show="all"):
    n=100
    counter=0
    images=list()
    vertical_images=[]
    rng_state = np.random.get_state()
    np.random.shuffle(train_images["id"])
    np.random.set_state(rng_state)
    np.random.shuffle(train_images["label"])
    for path, target in zip(train_images["id"], train_images["label"]):
        if target!=show and show!="all":
            continue
        counter=counter+1
        if counter%100==0:
            break
        #Image loading from disk as JpegImageFile file format
        img=load_img(path, target_size=(width,height))
        #Converting JpegImageFile to numpy array
        img=img_to_array(img)
        
        hside=get_side(img, side_type="horizontal")
        images.append(img)
        images.append(hside)

        if counter%10==0:
            himage=np.hstack((images))
            vside=get_side(himage, side_type="vertical")
            vertical_images.append(himage)
            vertical_images.append(vside)
            
            images=list()

    gallery=np.vstack((vertical_images)) 
    plt.figure(figsize=(12,12))
    plt.xticks([])
    plt.yticks([])
    title = {"all":"All Classifications's",
             "other":"Other",
             "covid":"Covid-19"}
    plt.title("100 Samples of {} Patients of the training set".format(title[show]))
    plt.imshow(gallery.astype(np.uint8))

# %%
show_gallery("all")

# %% [markdown]
# Data Generator

# %%
def get_data_generator(dataframe, x_col, y_col, subset=None, shuffle=True, batch_size=16, class_mode="binary"):
    datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=False,
    width_shift_range=0.1,
    height_shift_range=0.1)
    
    data_generator = datagen.flow_from_dataframe(
        dataframe=dataframe,
        x_col=x_col,
        y_col=y_col,
        subset=subset,
        target_size=(width, height),
        class_mode=class_mode,
        # color_mode="rgb",
        batch_size=batch_size,
        shuffle=shuffle,
    )
    return data_generator

# %% [markdown]
# See sample generated images

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = get_data_generator(example_df, "id", "label", class_mode = "categorical")

plt.figure(figsize = (12,12))
for i in range(0, 9):
        plt.subplot(3, 3, i+1)
        for X_batch, Y_batch in example_generator:
            image = X_batch[0]
            plt.imshow(image)
            break
plt.tight_layout()
plt.show()
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %% [markdown]
# Setting A Model With Transfer Learning

# %%
def get_model():
    from keras.applications import VGG16
    
    conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(width,height,3))
    
    conv_base.trainable = True
    set_trainable = False
    for layer in conv_base.layers:
        if layer.name == 'block3_conv1':
            set_trainable = True
        if set_trainable:
            layer.trainable = True
        else:
            layer.trainable = False
    
    model = Sequential()
    model.add(conv_base)
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(1024, activation='relu'))
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation = 'sigmoid'))
    
    model.compile(optimizer=optimizers.RMSprop(lr=2e-5),
                  loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
def train_model(model, train_df, validation_df, epochs, callbacks=[]):
    batch_size = 16
    train_generator = get_data_generator(train_df, "id", "label", batch_size=batch_size)
    validation_generator = get_data_generator(validation_df, "id", "label",batch_size=batch_size)

    #model.compile(
    #    optimizer="Adam", loss="binary_crossentropy", metrics=["accuracy"]
    #)

    step_size_train = train_generator.n // train_generator.batch_size
    step_size_validation = validation_generator.n // validation_generator.batch_size

    if step_size_train == 0:
        step_size_train = train_generator.n // 2
        step_size_validation = validation_generator.n // 2

    history = model.fit(
        train_generator,
        steps_per_epoch=step_size_train,
        epochs=epochs,
        validation_data=validation_generator,
        validation_steps=step_size_validation,
        callbacks=callbacks
    )
    
    #needed when a model is loaded
    np.save('transfer_learning_legend', train_generator.class_indices)
    
    return history.history

# %%
def plot_results(history):
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']

    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and Validation accuracy')
    plt.legend()

    plt.figure()

    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and Validation loss')
    plt.legend()

    plt.show()

# %% [markdown]
# Cross Validation

# %%
def get_dicts(train_folders_1, train_folders_2, validation_folders_1, validation_folders_2):
    train_set = dict(zip(train_folders_1, ['other' for i in range(len(train_folders_1))]))
    train_set.update(dict(zip(train_folders_2, ['covid' for i in range(len(train_folders_2))])))
    validation_set = dict(zip(validation_folders_1, ['other' for i in range(len(validation_folders_1))]))
    validation_set.update(dict(zip(validation_folders_2, ['covid' for i in range(len(validation_folders_2))])))
    return train_set, validation_set

# %%
def get_data(train_img_src_folder, train_img_folders, validation_img_src_folder, validation_img_folders):   
    dfs = []
    train_images = {"id": [], "label": []}
    validation_images = {"id": [], "label": []}

    df_config = [
        (train_img_src_folder, train_img_folders, train_images),
        (validation_img_src_folder, validation_img_folders, validation_images)
    ]
    
    for (base, folder, dic) in df_config:
        for img_folder, img_label in folder.items():
            search_folder = "{}/{}".format(base, img_folder)
            imgs_filename = sorted(get_file_path(search_folder, search_filter = 'segmented'))
            imgs_filename = imgs_filename[(len(imgs_filename)-EXAM_SLICE)//2:(len(imgs_filename)+EXAM_SLICE)//2]
            dic["id"].extend(imgs_filename)
            dic["label"].extend([img_label] * len(imgs_filename))

        dfs.append(pd.DataFrame(data=dic))

    train_df, validation_df = dfs[0], dfs[1]

    train_df.to_csv('train_df.csv', index=False)
    validation_df.to_csv('validation_df.csv', index=False)

    print("Train fold with {} images".format(len(train_df)))
    print(train_df.groupby("label").label.count())
    print()
    print("Validation fold with {} images".format(len(validation_df)))
    print(validation_df.groupby("label").label.count())
    print("-" * 30)
    
    return train_df, validation_df

# %%
def plot_all_acc(results):
    for history in results:
        acc = history['accuracy']
        val_acc = history['val_accuracy']
        loss = history['loss']
        val_loss = history['val_loss']

        epochs = range(1, len(acc) + 1)
        plt.plot(epochs, acc, 'bo', label='Training acc')
        plt.plot(epochs, val_acc, 'b', label='Validation acc')
        plt.title('Training and Validation accuracy')
        plt.legend()

        #plt.figure()
        plt.show()

# %%
def cross_validation(label_1_patients, label_2_patients, valid_num):
    all_results = []
    for i in range(0, len(label_1_patients), valid_num):
        validation_folders_1 = label_1_patients[i:i+valid_num]
        validation_folders_2 = label_2_patients[i:i+valid_num]
        train_folders_1 = list(set(label_1_patients) - set(validation_folders_1))
        train_folders_2 = list(set(label_2_patients) - set(validation_folders_2))
        
        print('Validating Folders: ', sorted(validation_folders_1), ',', sorted(validation_folders_2))
        print('Training Folders: ', sorted(train_folders_1), ',', sorted(train_folders_2))
        
        train_img_src_folder = img_src_folder
        validation_img_src_folder = img_src_folder
        
        train_set, validation_set = get_dicts(train_folders_1, train_folders_2, validation_folders_1, validation_folders_2)
        
        EXAM_SLICE = 200
        EPOCHS = 15
        width = 150
        height = 150
        
        train_df, validation_df = get_data(train_img_src_folder, train_set, validation_img_src_folder, validation_set)
        
        model = get_model()
        #model.summary()
        history = train_model(model, train_df, validation_df, EPOCHS)
        all_results.append(history)
    
    return all_results

# %%
def special_cross_validation(covid_patients, other_patients):
    all_results = []
    for i in range(0, 5):
        validation_other_patients = []
        validation_covid_patients = []
        
        validation_other_patients.append(other_patients[i])
        if (i+5) <= (len(other_patients)-1):
            validation_other_patients.append(other_patients[i+5])
        else:
            validation_other_patients.append(other_patients[i+4])
            
        validation_covid_patients.append(covid_patients[i])
        validation_covid_patients.append(covid_patients[i+5])
        
        train_covid_patients = list(set(covid_patients) - set(validation_covid_patients))
        train_other_patients = list(set(other_patients) - set(validation_other_patients))
        
        print('Validating Folders: ', sorted(validation_other_patients), ',', sorted(validation_covid_patients))
        print('Training Folders: ', sorted(train_other_patients), ',', sorted(train_covid_patients))
        
        train_img_src_folder = img_src_folder
        validation_img_src_folder = img_src_folder
        
        train_set, validation_set = get_dicts(train_covid_patients, train_other_patients, validation_covid_patients, validation_other_patients)
        
        EXAM_SLICE = 200
        EPOCHS = 20
        width = 150
        height = 150
        
        train_df, validation_df = get_data(train_img_src_folder, train_set, validation_img_src_folder, validation_set)
        
        model = get_model()
        #model.summary()
        history = train_model(model, train_df, validation_df, EPOCHS)
        all_results.append(history)
    
    return all_results

# %% [markdown]
# Fitting Cross Validation and Visualizing Results

# %%
sorted(other_patients)
# Out:
# ['p1', 'p10', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9']

# %%
sorted(covid_patients)
# Out:
# ['p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20']

# %%
covid_patients = sorted(covid_patients)
covid_patients
# Out:
# ['p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20']

# %%
other_patients = sorted(other_patients)
other_patients.pop(1)
other_patients.append('p10') #to display in the correct order
#removing p8
other_patients.pop(7)
other_patients
# Out:
# ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p9', 'p10']

# %%
results = special_cross_validation(covid_patients, other_patients)
# Out:
# Validating Folders:  ['p1', 'p6'] , ['p11', 'p16']
# Training Folders:  ['p10', 'p2', 'p3', 'p4', 'p5', 'p7', 'p9'] , ['p12', 'p13', 'p14', 'p15', 'p17', 'p18', 'p19', 'p20']
# Train fold with 3000 images
# label
# covid    1400
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3000 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/20
# 187/187 [==============================] - 107s 572ms/step - loss: 0.2883 - accuracy: 0.8616 - val_loss: 0.2081 - val_accuracy: 0.9212
# Epoch 2/20
# 187/187 [==============================] - 48s 257ms/step - loss: 0.0472 - accuracy: 0.9836 - val_loss: 0.4094 - val_accuracy: 0.9075
# Epoch 3/20
# 187/187 [==============================] - 46s 247ms/step - loss: 0.0267 - accuracy: 0.9940 - val_loss: 0.4965 - val_accuracy: 0.8938
# Epoch 4/20
# 187/187 [==============================] - 62s 334ms/step - loss: 0.0072 - accuracy: 0.9990 - val_loss: 0.3991 - val_accuracy: 0.9312
# Epoch 5/20
# 187/187 [==============================] - 64s 342ms/step - loss: 0.0229 - accuracy: 0.9956 - val_loss: 0.4592 - val_accuracy: 0.9300
# Epoch 6/20
# 187/187 [==============================] - 64s 342ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.8442 - val_accuracy: 0.9062
# Epoch 7/20
# 187/187 [==============================] - 69s 370ms/step - loss: 0.0091 - accuracy: 0.9980 - val_loss: 0.9862 - val_accuracy: 0.9038
# Epoch 8/20
# 187/187 [==============================] - 65s 346ms/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 0.4170 - val_accuracy: 0.9438
# Epoch 9/20
# 187/187 [==============================] - 65s 348ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.8436 - val_accuracy: 0.9000
# Epoch 10/20
# 187/187 [==============================] - 65s 345ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.7970 - val_accuracy: 0.9350
# Epoch 11/20
# 187/187 [==============================] - 65s 350ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.5874 - val_accuracy: 0.9413
# Epoch 12/20
# 187/187 [==============================] - 65s 350ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 1.1597 - val_accuracy: 0.9100
# Epoch 13/20
# 187/187 [==============================] - 66s 355ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 0.4800 - val_accuracy: 0.9600
# Epoch 14/20
# 187/187 [==============================] - 66s 355ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.6271 - val_accuracy: 0.9475
# Epoch 15/20
# 187/187 [==============================] - 66s 351ms/step - loss: 6.3501e-06 - accuracy: 1.0000 - val_loss: 1.9893 - val_accuracy: 0.9375
# Epoch 16/20
# 187/187 [==============================] - 66s 356ms/step - loss: 0.0160 - accuracy: 0.9987 - val_loss: 1.4648 - val_accuracy: 0.9400
# Epoch 17/20
# 187/187 [==============================] - 66s 355ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 1.1512 - val_accuracy: 0.9038
# Epoch 18/20
# 187/187 [==============================] - 65s 349ms/step - loss: 0.0124 - accuracy: 0.9993 - val_loss: 0.6328 - val_accuracy: 0.9350
# Epoch 19/20
# 187/187 [==============================] - 66s 350ms/step - loss: 0.0113 - accuracy: 0.9987 - val_loss: 0.6435 - val_accuracy: 0.9550
# Epoch 20/20
# 187/187 [==============================] - 67s 356ms/step - loss: 8.8160e-08 - accuracy: 1.0000 - val_loss: 1.3209 - val_accuracy: 0.9312
# Validating Folders:  ['p2', 'p7'] , ['p12', 'p17']
# Training Folders:  ['p1', 'p10', 'p3', 'p4', 'p5', 'p6', 'p9'] , ['p11', 'p13', 'p14', 'p15', 'p16', 'p18', 'p19', 'p20']
# Train fold with 3000 images
# label
# covid    1400
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3000 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/20
# 187/187 [==============================] - 109s 585ms/step - loss: 0.2456 - accuracy: 0.8867 - val_loss: 0.4972 - val_accuracy: 0.8313
# Epoch 2/20
# 187/187 [==============================] - 47s 251ms/step - loss: 0.0448 - accuracy: 0.9873 - val_loss: 0.2718 - val_accuracy: 0.9175
# Epoch 3/20
# 187/187 [==============================] - 70s 375ms/step - loss: 0.0253 - accuracy: 0.9923 - val_loss: 0.4125 - val_accuracy: 0.9137
# Epoch 4/20
# 187/187 [==============================] - 71s 381ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 1.0472 - val_accuracy: 0.8675
# Epoch 5/20
# 187/187 [==============================] - 66s 350ms/step - loss: 0.0229 - accuracy: 0.9973 - val_loss: 0.5227 - val_accuracy: 0.9350
# Epoch 6/20
# 187/187 [==============================] - 65s 349ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 0.3753 - val_accuracy: 0.9337
# Epoch 7/20
# 187/187 [==============================] - 67s 357ms/step - loss: 0.0078 - accuracy: 0.9987 - val_loss: 1.0883 - val_accuracy: 0.8462
# Epoch 8/20
# 187/187 [==============================] - 66s 355ms/step - loss: 0.0194 - accuracy: 0.9973 - val_loss: 0.2940 - val_accuracy: 0.9588
# Epoch 9/20
# 187/187 [==============================] - 67s 358ms/step - loss: 0.0159 - accuracy: 0.9983 - val_loss: 0.1945 - val_accuracy: 0.9688
# Epoch 10/20
# 187/187 [==============================] - 67s 359ms/step - loss: 0.0010 - accuracy: 0.9993 - val_loss: 1.1103 - val_accuracy: 0.9112
# Epoch 11/20
# 187/187 [==============================] - 67s 356ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 1.0757 - val_accuracy: 0.9112
# Epoch 12/20
# 187/187 [==============================] - 67s 360ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.5411 - val_accuracy: 0.9488
# Epoch 13/20
# 187/187 [==============================] - 55s 296ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 1.1451 - val_accuracy: 0.9062
# Epoch 14/20
# 187/187 [==============================] - 81s 433ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 1.7521 - val_accuracy: 0.8637
# Epoch 15/20
# 187/187 [==============================] - 57s 306ms/step - loss: 0.0106 - accuracy: 0.9993 - val_loss: 1.8053 - val_accuracy: 0.8388
# Epoch 16/20
# 187/187 [==============================] - 81s 431ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 2.1606 - val_accuracy: 0.8487
# Epoch 17/20
# 187/187 [==============================] - 67s 360ms/step - loss: 8.4473e-04 - accuracy: 0.9993 - val_loss: 0.2963 - val_accuracy: 0.9588
# Epoch 18/20
# 187/187 [==============================] - 71s 380ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 1.9964 - val_accuracy: 0.8675
# Epoch 19/20
# 187/187 [==============================] - 74s 394ms/step - loss: 0.0016 - accuracy: 0.9990 - val_loss: 0.6754 - val_accuracy: 0.9350
# Epoch 20/20
# 187/187 [==============================] - 58s 311ms/step - loss: 5.9630e-04 - accuracy: 0.9997 - val_loss: 0.9555 - val_accuracy: 0.9175
# Validating Folders:  ['p3', 'p9'] , ['p13', 'p18']
# Training Folders:  ['p1', 'p10', 'p2', 'p4', 'p5', 'p6', 'p7'] , ['p11', 'p12', 'p14', 'p15', 'p16', 'p17', 'p19', 'p20']
# Train fold with 3000 images
# label
# covid    1400
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3000 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/20
# 187/187 [==============================] - 83s 441ms/step - loss: 0.1526 - accuracy: 0.9328 - val_loss: 1.3763 - val_accuracy: 0.7462
# Epoch 2/20
# 187/187 [==============================] - 65s 347ms/step - loss: 0.0201 - accuracy: 0.9953 - val_loss: 2.7311 - val_accuracy: 0.7163
# Epoch 3/20
# 187/187 [==============================] - 75s 403ms/step - loss: 0.0317 - accuracy: 0.9963 - val_loss: 2.7427 - val_accuracy: 0.7200
# Epoch 4/20
# 187/187 [==============================] - 69s 371ms/step - loss: 0.0231 - accuracy: 0.9983 - val_loss: 2.6272 - val_accuracy: 0.7188
# Epoch 5/20
# 187/187 [==============================] - 70s 373ms/step - loss: 0.0145 - accuracy: 0.9987 - val_loss: 3.2179 - val_accuracy: 0.7200
# Epoch 6/20
# 187/187 [==============================] - 76s 408ms/step - loss: 0.0122 - accuracy: 0.9993 - val_loss: 3.4494 - val_accuracy: 0.7312
# Epoch 7/20
# 187/187 [==============================] - 81s 436ms/step - loss: 0.0085 - accuracy: 0.9980 - val_loss: 3.6494 - val_accuracy: 0.7163
# Epoch 8/20
# 187/187 [==============================] - 71s 379ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 5.2689 - val_accuracy: 0.6075
# Epoch 9/20
# 187/187 [==============================] - 84s 448ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 3.8884 - val_accuracy: 0.7300
# Epoch 10/20
# 187/187 [==============================] - 83s 445ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 3.8209 - val_accuracy: 0.7350
# Epoch 11/20
# 187/187 [==============================] - 90s 482ms/step - loss: 0.0098 - accuracy: 0.9983 - val_loss: 3.4770 - val_accuracy: 0.7638
# Epoch 12/20
# 187/187 [==============================] - 79s 423ms/step - loss: 0.0116 - accuracy: 0.9990 - val_loss: 4.4304 - val_accuracy: 0.7325
# Epoch 13/20
# 187/187 [==============================] - 77s 413ms/step - loss: 7.5089e-05 - accuracy: 1.0000 - val_loss: 4.1969 - val_accuracy: 0.7500
# Epoch 14/20
# 187/187 [==============================] - 76s 407ms/step - loss: 2.0199e-05 - accuracy: 1.0000 - val_loss: 7.0611 - val_accuracy: 0.7425
# Epoch 15/20
# 187/187 [==============================] - 77s 410ms/step - loss: 1.0720e-08 - accuracy: 1.0000 - val_loss: 5.6577 - val_accuracy: 0.7688
# Epoch 16/20
# 187/187 [==============================] - 73s 393ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 7.7781 - val_accuracy: 0.7275
# Epoch 17/20
# 187/187 [==============================] - 79s 421ms/step - loss: 7.4368e-06 - accuracy: 1.0000 - val_loss: 7.6179 - val_accuracy: 0.7150
# Epoch 18/20
# 187/187 [==============================] - 76s 406ms/step - loss: 5.6537e-10 - accuracy: 1.0000 - val_loss: 6.1259 - val_accuracy: 0.7575
# Epoch 19/20
# 187/187 [==============================] - 77s 411ms/step - loss: 6.2302e-11 - accuracy: 1.0000 - val_loss: 6.2614 - val_accuracy: 0.7525
# Epoch 20/20
# 187/187 [==============================] - 78s 416ms/step - loss: 3.9331e-10 - accuracy: 1.0000 - val_loss: 7.3122 - val_accuracy: 0.7088
# Validating Folders:  ['p10', 'p4'] , ['p14', 'p19']
# Training Folders:  ['p1', 'p2', 'p3', 'p5', 'p6', 'p7', 'p9'] , ['p11', 'p12', 'p13', 'p15', 'p16', 'p17', 'p18', 'p20']
# Train fold with 3000 images
# label
# covid    1400
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3000 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/20
# 187/187 [==============================] - 92s 494ms/step - loss: 0.2575 - accuracy: 0.8854 - val_loss: 0.2612 - val_accuracy: 0.9050
# Epoch 2/20
# 187/187 [==============================] - 88s 472ms/step - loss: 0.0453 - accuracy: 0.9832 - val_loss: 0.8038 - val_accuracy: 0.8438
# Epoch 3/20
# 187/187 [==============================] - 83s 445ms/step - loss: 0.0260 - accuracy: 0.9956 - val_loss: 0.3529 - val_accuracy: 0.8963
# Epoch 4/20
# 187/187 [==============================] - 97s 521ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.6079 - val_accuracy: 0.8288
# Epoch 5/20
# 187/187 [==============================] - 89s 478ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 1.0768 - val_accuracy: 0.8675
# Epoch 6/20
# 187/187 [==============================] - 88s 471ms/step - loss: 0.0165 - accuracy: 0.9966 - val_loss: 0.4205 - val_accuracy: 0.8725
# Epoch 7/20
# 187/187 [==============================] - 84s 449ms/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 2.3936 - val_accuracy: 0.8150
# Epoch 8/20
# 187/187 [==============================] - 88s 470ms/step - loss: 0.0060 - accuracy: 0.9993 - val_loss: 1.3341 - val_accuracy: 0.7775
# Epoch 9/20
# 187/187 [==============================] - 88s 470ms/step - loss: 5.5941e-04 - accuracy: 0.9997 - val_loss: 1.5396 - val_accuracy: 0.8938
# Epoch 10/20
# 187/187 [==============================] - 86s 462ms/step - loss: 0.0082 - accuracy: 0.9987 - val_loss: 1.6067 - val_accuracy: 0.8525
# Epoch 11/20
# 187/187 [==============================] - 85s 453ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.5128 - val_accuracy: 0.9038
# Epoch 12/20
# 187/187 [==============================] - 85s 454ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 1.1006 - val_accuracy: 0.8275
# Epoch 13/20
# 187/187 [==============================] - 84s 448ms/step - loss: 0.0068 - accuracy: 0.9987 - val_loss: 4.8044 - val_accuracy: 0.6550
# Epoch 14/20
# 187/187 [==============================] - 81s 435ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.1831 - val_accuracy: 0.9588
# Epoch 15/20
# 187/187 [==============================] - 81s 435ms/step - loss: 4.4872e-07 - accuracy: 1.0000 - val_loss: 0.9468 - val_accuracy: 0.9000
# Epoch 16/20
# 187/187 [==============================] - 84s 451ms/step - loss: 3.8483e-10 - accuracy: 1.0000 - val_loss: 1.1565 - val_accuracy: 0.9000
# Epoch 17/20
# 187/187 [==============================] - 79s 421ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 3.5105 - val_accuracy: 0.7487
# Epoch 18/20
# 187/187 [==============================] - 80s 430ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 1.2862 - val_accuracy: 0.8750
# Epoch 19/20
# 187/187 [==============================] - 78s 419ms/step - loss: 2.8094e-08 - accuracy: 1.0000 - val_loss: 1.3881 - val_accuracy: 0.8600
# Epoch 20/20
# 187/187 [==============================] - 79s 420ms/step - loss: 3.0688e-08 - accuracy: 1.0000 - val_loss: 2.5432 - val_accuracy: 0.8062
# Validating Folders:  ['p10', 'p5'] , ['p15', 'p20']
# Training Folders:  ['p1', 'p2', 'p3', 'p4', 'p6', 'p7', 'p9'] , ['p11', 'p12', 'p13', 'p14', 'p16', 'p17', 'p18', 'p19']
# Train fold with 3000 images
# label
# covid    1400
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3000 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/20
# 187/187 [==============================] - 112s 598ms/step - loss: 0.2690 - accuracy: 0.8747 - val_loss: 0.1518 - val_accuracy: 0.9325
# Epoch 2/20
# 187/187 [==============================] - 83s 445ms/step - loss: 0.0483 - accuracy: 0.9869 - val_loss: 0.1935 - val_accuracy: 0.9250
# Epoch 3/20
# 187/187 [==============================] - 80s 428ms/step - loss: 0.0225 - accuracy: 0.9936 - val_loss: 0.3069 - val_accuracy: 0.8875
# Epoch 4/20
# 187/187 [==============================] - 79s 422ms/step - loss: 0.0266 - accuracy: 0.9943 - val_loss: 0.2167 - val_accuracy: 0.9150
# Epoch 5/20
# 187/187 [==============================] - 79s 423ms/step - loss: 0.0127 - accuracy: 0.9977 - val_loss: 0.1707 - val_accuracy: 0.9525
# Epoch 6/20
# 187/187 [==============================] - 80s 427ms/step - loss: 0.0237 - accuracy: 0.9960 - val_loss: 0.1683 - val_accuracy: 0.9375
# Epoch 7/20
# 187/187 [==============================] - 117s 624ms/step - loss: 0.0202 - accuracy: 0.9966 - val_loss: 0.8252 - val_accuracy: 0.8075
# Epoch 8/20
# 187/187 [==============================] - 183s 978ms/step - loss: 2.0959e-04 - accuracy: 1.0000 - val_loss: 1.3298 - val_accuracy: 0.8338
# Epoch 9/20
# 187/187 [==============================] - 182s 972ms/step - loss: 0.0106 - accuracy: 0.9973 - val_loss: 1.5098 - val_accuracy: 0.7688
# Epoch 10/20
# 187/187 [==============================] - 93s 495ms/step - loss: 0.0015 - accuracy: 0.9990 - val_loss: 0.3311 - val_accuracy: 0.9438
# Epoch 11/20
# 187/187 [==============================] - 134s 715ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.0551 - val_accuracy: 0.9812
# Epoch 12/20
# 187/187 [==============================] - 126s 675ms/step - loss: 1.5026e-06 - accuracy: 1.0000 - val_loss: 0.0581 - val_accuracy: 0.9862
# Epoch 13/20
# 187/187 [==============================] - 74s 395ms/step - loss: 7.0352e-09 - accuracy: 1.0000 - val_loss: 0.3677 - val_accuracy: 0.9513
# Epoch 14/20
# 187/187 [==============================] - 84s 449ms/step - loss: 4.9754e-10 - accuracy: 1.0000 - val_loss: 0.2487 - val_accuracy: 0.9575
# Epoch 15/20
# 187/187 [==============================] - 83s 443ms/step - loss: 1.3036e-08 - accuracy: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.9600
# Epoch 16/20
# 187/187 [==============================] - 85s 455ms/step - loss: 7.1152e-09 - accuracy: 1.0000 - val_loss: 0.3004 - val_accuracy: 0.9463
# Epoch 17/20
# 187/187 [==============================] - 84s 449ms/step - loss: 2.3101e-09 - accuracy: 1.0000 - val_loss: 0.6452 - val_accuracy: 0.9275
# Epoch 18/20
# 187/187 [==============================] - 80s 428ms/step - loss: 6.5597e-10 - accuracy: 1.0000 - val_loss: 0.3803 - val_accuracy: 0.9500
# Epoch 19/20
# 187/187 [==============================] - 81s 435ms/step - loss: 0.0057 - accuracy: 0.9993 - val_loss: 0.4654 - val_accuracy: 0.9250
# Epoch 20/20
# 187/187 [==============================] - 82s 439ms/step - loss: 0.0052 - accuracy: 0.9997 - val_loss: 0.8903 - val_accuracy: 0.8675

# %%
plot_all_acc(results)

# %% [markdown]
# Fitting or Loading a Final Model

# %%
model = get_model()

# %%
print(sorted(covid_patients))
print(sorted(other_patients))
# Out:
# ['p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20']
# ['p1', 'p10', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9']

# %%
def get_file_path(folder, search_filter=''):
    paths = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            path = os.path.join(root, file)
            if search_filter in path:
                paths.append(path)
    return paths

# %%
#fitting a model that performed well in cross validation tests
validation_other_folders = ['p2', 'p7']
validation_covid_folders = ['p12', 'p17']

train_other_folders = list(set(other_patients) - set(validation_other_folders))
train_covid_folders = list(set(covid_patients) - set(validation_covid_folders))

print("Validating Folders: ", sorted(validation_other_folders), sorted(validation_covid_folders))
print("Training Folders: ", sorted(train_other_folders), sorted(train_covid_folders))

train_img_src_folder = img_src_folder
validation_img_src_folder = img_src_folder

train_set, validation_set = get_dicts(train_other_folders, train_covid_folders,
                                    validation_other_folders, validation_covid_folders)

train_df, validation_df = get_data(train_img_src_folder, train_set, 
                                  validation_img_src_folder, validation_set)

history = train_model(model, train_df, validation_df, EPOCHS)
# Out:
# Validating Folders:  ['p2', 'p7'] ['p12', 'p17']
# Training Folders:  ['p1', 'p10', 'p3', 'p4', 'p5', 'p6', 'p8', 'p9'] ['p11', 'p13', 'p14', 'p15', 'p16', 'p18', 'p19', 'p20']
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3200 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/15
# 200/200 [==============================] - 140s 702ms/step - loss: 0.2459 - accuracy: 0.8953 - val_loss: 0.1848 - val_accuracy: 0.9125
# Epoch 2/15
# 200/200 [==============================] - 122s 609ms/step - loss: 0.0407 - accuracy: 0.9869 - val_loss: 0.2954 - val_accuracy: 0.9000
# Epoch 3/15
# 200/200 [==============================] - 44s 222ms/step - loss: 0.0188 - accuracy: 0.9944 - val_loss: 0.6703 - val_accuracy: 0.8450
# Epoch 4/15
# 200/200 [==============================] - 41s 207ms/step - loss: 0.0146 - accuracy: 0.9972 - val_loss: 0.5936 - val_accuracy: 0.8737
# Epoch 5/15
# 200/200 [==============================] - 44s 218ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.3563 - val_accuracy: 0.9125
# Epoch 6/15
# 200/200 [==============================] - 57s 284ms/step - loss: 0.0108 - accuracy: 0.9978 - val_loss: 0.5633 - val_accuracy: 0.8913
# Epoch 7/15
# 200/200 [==============================] - 51s 257ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.9287 - val_accuracy: 0.8575
# Epoch 8/15
# 200/200 [==============================] - 56s 278ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.8819 - val_accuracy: 0.8675
# Epoch 9/15
# 200/200 [==============================] - 55s 273ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 1.3962 - val_accuracy: 0.8725
# Epoch 10/15
# 200/200 [==============================] - 55s 276ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 0.2992 - val_accuracy: 0.9475
# Epoch 11/15
# 200/200 [==============================] - 55s 276ms/step - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.5257 - val_accuracy: 0.9200
# Epoch 12/15
# 200/200 [==============================] - 56s 278ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 1.1880 - val_accuracy: 0.8662
# Epoch 13/15
# 200/200 [==============================] - 56s 279ms/step - loss: 0.0124 - accuracy: 0.9991 - val_loss: 0.6603 - val_accuracy: 0.9062
# Epoch 14/15
# 200/200 [==============================] - 56s 281ms/step - loss: 0.0051 - accuracy: 0.9991 - val_loss: 5.0343 - val_accuracy: 0.6250
# Epoch 15/15
# 200/200 [==============================] - 57s 287ms/step - loss: 0.0156 - accuracy: 0.9978 - val_loss: 0.6902 - val_accuracy: 0.9038

# %%
#saving the final model
model.save('transfer_learning.h5')

# %%
if os.path.isfile('transfer_learning.h5'):
    from keras.models import load_model
    model = load_model('transfer_learning.h5')
    model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 15,076,865
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %% [markdown]
# Making Predictions to Patients in Test Set

# %%
test_patients = sorted(TEST_IMG_FOLDERS) 
test_patients

# %%
if len(test_patients)>0:
    batch_size = 16
    width = 150
    height = 150
    results = []
    for p in test_patients:
        curr_dir = img_src_folder + '/' + p + '/segmented/' 
        test_filenames = os.listdir(curr_dir)
        test_df = pd.DataFrame({
                'filename': test_filenames
         })
        nb_samples = test_df.shape[0]

        test_gen = ImageDataGenerator(rescale=1./255)
        test_generator = test_gen.flow_from_dataframe(
                test_df, 
                curr_dir, 
                x_col='filename',
                y_col=None,
                class_mode=None,
                target_size=(width, height),
                batch_size=batch_size,
                shuffle=False
        )

        predict = model.predict(test_generator, steps=np.ceil(nb_samples/batch_size))
        test_df['category'] = [int(round(p[0])) for p in predict]
        results.append(test_df)

# %% [markdown]
# Class Activation Map

# %%
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

img_path = 'lung-segmentation/uniq/p11/segmented/132449.497359_I2350000.png'

img = image.load_img(img_path, target_size=(150,150))

x = img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)
x
# Out:
# array([[[[ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          ...,
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ]],
#
#         [[ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          ...,
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ]],
#
#         [[ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          ...,
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ]],
#
#         ...,
#
#         [[ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          ...,
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ]],
#
#         [[ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          ...,
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ]],
#
#         [[ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          ...,
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ],
#          [ -75.939,  -96.779, -103.68 ]]]], dtype=float32)

# %%
if os.path.isfile('transfer_learning_legend.npy'):
        class_indices = np.load('transfer_learning_legend.npy', allow_pickle=True).item()
        class_indices = dict((v,k) for k,v in class_indices.items())

# %%
class_indices
# Out:
# {0: 'covid', 1: 'other'}

# %%
a = [int(round(p[0])) for p in preds]
class_indices[a[0]]
# Out:
# 'covid'

# %%
preds = model.predict(x)
predictions = pd.DataFrame(decode_predictions(preds, top=3)[0],columns=['col1','category','probability']).iloc[:,1:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-68b24e3c00c7> in <module>
#       1 preds = model.predict(x)
# ----> 2 predictions = pd.DataFrame(decode_predictions(preds, top=3)[0],columns=['col1','category','probability']).iloc[:,1:]
#
# ~/.conda/envs/ai/lib/python3.8/site-packages/tensorflow/python/keras/applications/vgg16.py in decode_predictions(preds, top)
#     250     ValueError: In case of invalid shape of the `preds` array (must be 2D).
#     251   """
# --> 252   return imagenet_utils.decode_predictions(preds, top=top)
#     253
#     254
#
# ~/.conda/envs/ai/lib/python3.8/site-packages/tensorflow/python/keras/applications/imagenet_utils.py in decode_predictions(preds, top)
#     135
#     136   if len(preds.shape) != 2 or preds.shape[1] != 1000:
# --> 137     raise ValueError('`decode_predictions` expects '
#     138                      'a batch of predictions '
#     139                      '(i.e. a 2D array of shape (samples, 1000)). '
#
# ValueError: `decode_predictions` expects a batch of predictions (i.e. a 2D array of shape (samples, 1000)). Found array with shape: (1, 1)

# %%
from keras import backend as K

covid_output = model.output[:, 0]
covid_output

last_conv_layer = model.get_layer('vgg16')
last_conv_layer = last_conv_layer.get_layer('block5_conv3')

grads = K.gradients(covid_output, last_conv_layer.output)[0]

pooled_grads = K.mean(grads, axis=(0, 1, 2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-976d4480e178> in <module>
#       9 grads = K.gradients(covid_output, last_conv_layer.output)[0]
#      10
# ---> 11 pooled_grads = K.mean(grads, axis=(0, 1, 2))
#
# ~/.conda/envs/ai/lib/python3.8/site-packages/keras/backend/tensorflow_backend.py in mean(x, axis, keepdims)
#    1808     {{np_implementation}}
#    1809     """
# -> 1810     if x.dtype.base_dtype == tf.bool:
#    1811         x = tf.cast(x, floatx())
#    1812     return tf.reduce_mean(x, axis, keepdims)
#
# AttributeError: 'NoneType' object has no attribute 'dtype'

# %%
img_path_y = 'lung-segmentation/uniq/p5/segmented/144924.394315_I1680000.png'

img_y = image.load_img(img_path_y, target_size=(150,150))

y = img_to_array(img_y)

y = np.expand_dims(y, axis=0)

y = preprocess_input(y)

# %%
preds_y = model.predict(y)

# %%
preds_y
# Out:
# array([[1.]], dtype=float32)
