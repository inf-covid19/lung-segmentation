# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import random

from keras import layers
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras import models
from keras import optimizers
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from keras import applications

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

import glob
import os
from datetime import datetime
# Out:
# Using TensorFlow backend.

# %%
img_src_folder = "lung-segmentation/uniq"
os.listdir(img_src_folder)
# Out:
# ['p17',
#  'p5',
#  'p7',
#  'multigif.py',
#  'p13',
#  'p11',
#  'p16',
#  'p6',
#  'p8',
#  'p15',
#  'p14',
#  'p1',
#  'p4',
#  'p18',
#  'p3',
#  'p19',
#  'p12',
#  'p9',
#  'p10',
#  'p2',
#  'gifs.zip',
#  'p20']

# %%
#1-5: normal patients, 11-20: covid patients.
other_patients = []
covid_patients = []
for root, dirs, files in os.walk(img_src_folder):
    for d in dirs:
        if d[0] == 'p':
            num = int(d[1:])
            if num <= 10: other_patients.append(d)
            elif num >= 11: covid_patients.append(d)

# %%
sorted(other_patients)
# Out:
# ['p1', 'p10', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9']

# %%
sorted(covid_patients)
# Out:
# ['p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20']

# %%
now = datetime.now()
#defining the minimum number of patients of each class that will be in the test set.
test_patients_per_label = 0
#building the test set with the declared num of patients of each class
TEST_IMG_FOLDERS = sorted(other_patients)[0:test_patients_per_label]
TEST_IMG_FOLDERS = sorted(covid_patients)[0:test_patients_per_label]

#splitting the test data and the rest (training and validation)
if test_patients_per_label > 0:
    for n in range(test_patients_per_label):
        other_patients.pop(0)
        covid_patients.pop(0)
        
#defining the number of patients in training set
num_train_patients = int(0.8*min(len(other_patients), len(covid_patients)))
        
train_other_folders = sorted(other_patients)[0:num_train_patients]
train_label_1 = ['other' for i in range(len(train_other_folders))]

validation_other_folders = list(set(other_patients) - set(train_other_folders))
validation_label_1 = ['other' for i in range(len(validation_other_folders))]

train_covid_folders = sorted(covid_patients)[0:num_train_patients]
train_label_2 = ['covid' for i in range(len(train_covid_folders))]

validation_covid_folders = list(set(covid_patients) - set(train_covid_folders))
validation_label_2 = ['covid' for i in range(len(validation_covid_folders))]

#balancing validation set members for each label (other or covid)
label_1_size = len(validation_other_folders)
label_2_size = len(validation_covid_folders)
dif = label_1_size - label_2_size
if dif != 0:
    greater_label = validation_other_folders #supposing one label as having more elements
    if label_2_size > label_1_size:
        greater_label = validation_covid_folders
        dif = abs(dif)
    for n in range(dif): #deletes an random majoritary's label patient until labels are balanced
        index = random.randint(0, len(greater_label) - 1)
        TEST_IMG_FOLDERS.append(greater_label[index])
        greater_label.pop(index)

TRAIN_IMG_SRC_FOLDER = img_src_folder
VALIDATION_IMG_SRC_FOLDER = img_src_folder
TEST_IMG_SRC_FOLDER = img_src_folder

TRAIN_IMG_FOLDERS = dict(zip(train_other_folders, train_label_1))
TRAIN_IMG_FOLDERS.update(dict(zip(train_covid_folders, train_label_2)))

VALIDATION_IMG_FOLDERS = dict(zip(validation_other_folders, validation_label_1))
VALIDATION_IMG_FOLDERS.update(dict(zip(validation_covid_folders, validation_label_2)))

# %%
TRAIN_IMG_FOLDERS
# Out:
# {'p1': 'other',
#  'p10': 'other',
#  'p2': 'other',
#  'p3': 'other',
#  'p4': 'other',
#  'p5': 'other',
#  'p6': 'other',
#  'p7': 'other',
#  'p11': 'covid',
#  'p12': 'covid',
#  'p13': 'covid',
#  'p14': 'covid',
#  'p15': 'covid',
#  'p16': 'covid',
#  'p17': 'covid',
#  'p18': 'covid'}

# %%
VALIDATION_IMG_FOLDERS
# Out:
# {'p9': 'other', 'p8': 'other', 'p20': 'covid', 'p19': 'covid'}

# %%
TEST_IMG_FOLDERS
# Out:
# []

# %%
CLASSES = len(set([label for label in TRAIN_IMG_FOLDERS.values()]))
EXAM_SLICE = 200
EPOCHS = 10
width = 400
height = 400
print(CLASSES)
# Out:
# 2

# %%
dfs = []
train_images = {"id": [], "label": []}
validation_images = {"id": [], "label": []}

df_config = [
    (TRAIN_IMG_SRC_FOLDER, TRAIN_IMG_FOLDERS, train_images),
    (VALIDATION_IMG_SRC_FOLDER, VALIDATION_IMG_FOLDERS, validation_images)
]

def get_file_path(folder, search_filter=''):
    paths = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            path = os.path.join(root, file)
            if search_filter in path:
                paths.append(path)
    return paths

for (base, folder, dic) in df_config:
    for img_folder, img_label in folder.items():
        search_folder = "{}/{}".format(base, img_folder)
        imgs_filename = sorted(get_file_path(search_folder, search_filter = 'segmented'))
        imgs_filename = imgs_filename[(len(imgs_filename)-EXAM_SLICE)//2:(len(imgs_filename)+EXAM_SLICE)//2]
        dic["id"].extend(imgs_filename)
        dic["label"].extend([img_label] * len(imgs_filename))
        
    dfs.append(pd.DataFrame(data=dic))

train_df, validation_df = dfs[0], dfs[1]

train_df.to_csv('train_df.csv', index=False)
validation_df.to_csv('validation_df.csv', index=False)

print("Train fold with {} images".format(len(train_df)))
print(train_df.groupby("label").label.count())
print()
print("Validation fold with {} images".format(len(validation_df)))
print(validation_df.groupby("label").label.count())
print("-" * 30)
# Out:
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------

# %% [markdown]
# Random Visualization of Training Data Samples

# %%
def get_side(img, side_type, side_size=5):
    height, width, channel=img.shape
    if side_type=="horizontal":
        return np.ones((height,side_size,  channel), dtype=np.float32)*255
        
    return np.ones((side_size, width,  channel), dtype=np.float32)*255

def show_gallery(show="all"):
    n=100
    counter=0
    images=list()
    vertical_images=[]
    rng_state = np.random.get_state()
    np.random.shuffle(train_images["id"])
    np.random.set_state(rng_state)
    np.random.shuffle(train_images["label"])
    for path, target in zip(train_images["id"], train_images["label"]):
        if target!=show and show!="all":
            continue
        counter=counter+1
        if counter%100==0:
            break
        #Image loading from disk as JpegImageFile file format
        img=load_img(path, target_size=(width,height))
        #Converting JpegImageFile to numpy array
        img=img_to_array(img)
        
        hside=get_side(img, side_type="horizontal")
        images.append(img)
        images.append(hside)

        if counter%10==0:
            himage=np.hstack((images))
            vside=get_side(himage, side_type="vertical")
            vertical_images.append(himage)
            vertical_images.append(vside)
            
            images=list()

    gallery=np.vstack((vertical_images)) 
    plt.figure(figsize=(12,12))
    plt.xticks([])
    plt.yticks([])
    title = {"all":"All Classifications's",
             "other":"Other",
             "covid":"Covid-19"}
    plt.title("100 Samples of {} Patients of the training set".format(title[show]))
    plt.imshow(gallery.astype(np.uint8))

# %%
show_gallery("all")

# %% [markdown]
# Data Generator

# %%
def get_data_generator(dataframe, x_col, y_col, subset=None, shuffle=True, batch_size=16, class_mode="binary"):
    datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=False,
    width_shift_range=0.1,
    height_shift_range=0.1)
    
    data_generator = datagen.flow_from_dataframe(
        dataframe=dataframe,
        x_col=x_col,
        y_col=y_col,
        subset=subset,
        target_size=(width, height),
        class_mode=class_mode,
        # color_mode="rgb",
        batch_size=batch_size,
        shuffle=shuffle,
    )
    return data_generator

# %% [markdown]
# See sample generated images

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = get_data_generator(example_df, "id", "label", class_mode = "categorical")

plt.figure(figsize = (12,12))
for i in range(0, 9):
        plt.subplot(3, 3, i+1)
        for X_batch, Y_batch in example_generator:
            image = X_batch[0]
            plt.imshow(image)
            break
plt.tight_layout()
plt.show()
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %% [markdown]
# Building model from scratch

# %%
def get_model(height, width):
    classifier= Sequential()

    classifier.add(Convolution2D(32, (3, 3), input_shape=(height, width, 3), activation= 'relu'))
    classifier.add(MaxPooling2D(pool_size= (2,2)))

    classifier.add(Convolution2D(64, (3, 3), activation= 'relu'))
    classifier.add(MaxPooling2D(pool_size= (2,2)))

    classifier.add(Convolution2D(128, (3, 3), activation= 'relu'))
    classifier.add(MaxPooling2D(pool_size= (2,2)))

    classifier.add(Convolution2D(128, (3, 3), activation = 'relu'))
    classifier.add(MaxPooling2D(pool_size= (2,2)))
    
    classifier.add(Convolution2D(256, (3, 3), activation = 'relu'))
    #classifier.add(MaxPooling2D(pool_size= (2,2)))
    
    classifier.add(Convolution2D(256, (3, 3), activation = 'relu'))
    classifier.add(MaxPooling2D(pool_size= (2,2)))
    
    classifier.add(Convolution2D(512, (3, 3), activation = 'relu'))
    #classifier.add(MaxPooling2D(pool_size= (2,2)))
    
    classifier.add(Convolution2D(512, (3, 3), activation = 'relu'))
    classifier.add(MaxPooling2D(pool_size= (2,2)))
    
    classifier.add(Flatten())
    
    #classifier.add(Dropout(0.3))
    #classifier.add(Dense(units= 1024, activation= 'relu'))
    
    classifier.add(Dropout(0.3))
    classifier.add(Dense(units= 512, activation= 'relu'))
    
    #classifier.add(Dropout(0.3))
    classifier.add(Dense(units= 1, activation= 'sigmoid'))

    #classifier.summary()
    opt = optimizers.Adam(learning_rate=0.0001)
    classifier.compile(optimizer= opt, loss= 'binary_crossentropy' ,metrics= ['accuracy'])

    return classifier

# %%
def train_model(model, train_df, validation_df, epochs, callbacks=[]):
    batch_size = 16
    train_generator = get_data_generator(train_df, "id", "label", batch_size=batch_size)
    validation_generator = get_data_generator(validation_df, "id", "label",batch_size=batch_size)

    #model.compile(
    #    optimizer="Adam", loss="binary_crossentropy", metrics=["accuracy"]
    #)

    step_size_train = train_generator.n // train_generator.batch_size
    step_size_validation = validation_generator.n // validation_generator.batch_size

    if step_size_train == 0:
        step_size_train = train_generator.n // 2
        step_size_validation = validation_generator.n // 2

    history = model.fit(
        train_generator,
        steps_per_epoch=step_size_train,
        epochs=epochs,
        validation_data=validation_generator,
        validation_steps=step_size_validation,
        callbacks=callbacks
    )
    
    #needed when a model is loaded
    np.save('label_legend', train_generator.class_indices)
    
    return history.history

# %%
def plot_results(history):
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']

    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and Validation accuracy')
    plt.legend()

    plt.figure()

    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and Validation loss')
    plt.legend()

    plt.show()

# %% [markdown]
# Cross Validation

# %%
def get_dicts(train_folders_1, train_folders_2, validation_folders_1, validation_folders_2):
    train_set = dict(zip(train_folders_1, ['other' for i in range(len(train_folders_1))]))
    train_set.update(dict(zip(train_folders_2, ['covid' for i in range(len(train_folders_2))])))
    validation_set = dict(zip(validation_folders_1, ['other' for i in range(len(validation_folders_1))]))
    validation_set.update(dict(zip(validation_folders_2, ['covid' for i in range(len(validation_folders_2))])))
    return train_set, validation_set

# %%
def get_data(train_img_src_folder, train_img_folders, validation_img_src_folder, validation_img_folders):   
    dfs = []
    train_images = {"id": [], "label": []}
    validation_images = {"id": [], "label": []}

    df_config = [
        (train_img_src_folder, train_img_folders, train_images),
        (validation_img_src_folder, validation_img_folders, validation_images)
    ]
    
    for (base, folder, dic) in df_config:
        for img_folder, img_label in folder.items():
            search_folder = "{}/{}".format(base, img_folder)
            imgs_filename = sorted(get_file_path(search_folder, search_filter = 'segmented'))
            imgs_filename = imgs_filename[(len(imgs_filename)-EXAM_SLICE)//2:(len(imgs_filename)+EXAM_SLICE)//2]
            dic["id"].extend(imgs_filename)
            dic["label"].extend([img_label] * len(imgs_filename))

        dfs.append(pd.DataFrame(data=dic))

    train_df, validation_df = dfs[0], dfs[1]

    train_df.to_csv('train_df.csv', index=False)
    validation_df.to_csv('validation_df.csv', index=False)

    print("Train fold with {} images".format(len(train_df)))
    print(train_df.groupby("label").label.count())
    print()
    print("Validation fold with {} images".format(len(validation_df)))
    print(validation_df.groupby("label").label.count())
    print("-" * 30)
    
    return train_df, validation_df

# %%
def plot_all_acc(results):
    for history in results:
        acc = history['accuracy']
        val_acc = history['val_accuracy']
        loss = history['loss']
        val_loss = history['val_loss']

        epochs = range(1, len(acc) + 1)
        plt.plot(epochs, acc, 'bo', label='Training acc')
        plt.plot(epochs, val_acc, 'b', label='Validation acc')
        plt.title('Training and Validation accuracy')
        plt.legend()

        #plt.figure()
        plt.show()

# %%
def cross_validation(label_1_patients, label_2_patients, valid_num):
    all_results = []
    for i in range(0, len(label_1_patients), valid_num):
        validation_folders_1 = label_1_patients[i:i+valid_num]
        validation_folders_2 = label_2_patients[i:i+valid_num]
        train_folders_1 = list(set(label_1_patients) - set(validation_folders_1))
        train_folders_2 = list(set(label_2_patients) - set(validation_folders_2))
        
        print('Validating Folders: ', sorted(validation_folders_1), ',', sorted(validation_folders_2))
        print('Training Folders: ', sorted(train_folders_1), ',', sorted(train_folders_2))
        
        train_img_src_folder = img_src_folder
        validation_img_src_folder = img_src_folder
        
        train_set, validation_set = get_dicts(train_folders_1, train_folders_2, validation_folders_1, validation_folders_2)
        
        EXAM_SLICE = 200
        EPOCHS = 20
        width = 400
        height = 400
        
        train_df, validation_df = get_data(train_img_src_folder, train_set, validation_img_src_folder, validation_set)
        
        model = get_model(height, width)
        #model.summary()
        history = train_model(model, train_df, validation_df, EPOCHS)
        all_results.append(history)
    
    return all_results

# %%
def special_cross_validation(covid_patients, other_patients):
    all_results = []
    for i in range(0, 5):
        validation_other_patients = []
        validation_covid_patients = []
        
        validation_other_patients.append(other_patients[i])
        validation_other_patients.append(other_patients[i+5])
        
        validation_covid_patients.append(covid_patients[i])
        validation_covid_patients.append(covid_patients[i+5])
        
        train_covid_patients = list(set(covid_patients) - set(validation_covid_patients))
        train_other_patients = list(set(other_patients) - set(validation_other_patients))
        
        print('Validating Folders: ', sorted(validation_other_patients), ',', sorted(validation_covid_patients))
        print('Training Folders: ', sorted(train_other_patients), ',', sorted(train_covid_patients))
        
        train_img_src_folder = img_src_folder
        validation_img_src_folder = img_src_folder
        
        train_set, validation_set = get_dicts(train_covid_patients, train_other_patients, validation_covid_patients, validation_other_patients)
        
        EXAM_SLICE = 200
        EPOCHS = 35
        width = 400
        height = 400
        
        train_df, validation_df = get_data(train_img_src_folder, train_set, validation_img_src_folder, validation_set)
        
        model = get_model(height, width)
        #model.summary()
        history = train_model(model, train_df, validation_df, EPOCHS)
        all_results.append(history)
    
    return all_results

# %% [markdown]
# Fitting Cross Validation and Visualizing Results

# %%
sorted(other_patients)
# Out:
# ['p1', 'p10', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9']

# %%
sorted(covid_patients)
# Out:
# ['p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20']

# %%
covid_patients = sorted(covid_patients)
covid_patients
# Out:
# ['p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20']

# %%
other_patients.append('p10')
other_patients
# Out:
# ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10']

# %%
results = special_cross_validation(covid_patients, other_patients)
# Out:
# Validating Folders:  ['p1', 'p6'] , ['p11', 'p16']
# Training Folders:  ['p10', 'p2', 'p3', 'p4', 'p5', 'p7', 'p8', 'p9'] , ['p12', 'p13', 'p14', 'p15', 'p17', 'p18', 'p19', 'p20']
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3200 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/35
# 200/200 [==============================] - 227s 1s/step - loss: 0.6197 - accuracy: 0.6503 - val_loss: 0.9548 - val_accuracy: 0.7387
# Epoch 2/35
# 200/200 [==============================] - 196s 979ms/step - loss: 0.3284 - accuracy: 0.8603 - val_loss: 1.8246 - val_accuracy: 0.5850
# Epoch 3/35
# 200/200 [==============================] - 187s 933ms/step - loss: 0.1919 - accuracy: 0.9244 - val_loss: 1.3123 - val_accuracy: 0.6162
# Epoch 4/35
# 200/200 [==============================] - 282s 1s/step - loss: 0.1369 - accuracy: 0.9425 - val_loss: 1.4449 - val_accuracy: 0.7275
# Epoch 5/35
# 200/200 [==============================] - 302s 2s/step - loss: 0.0971 - accuracy: 0.9600 - val_loss: 0.8612 - val_accuracy: 0.7675
# Epoch 6/35
# 200/200 [==============================] - 286s 1s/step - loss: 0.0655 - accuracy: 0.9759 - val_loss: 0.4584 - val_accuracy: 0.8813
# Epoch 7/35
# 200/200 [==============================] - 317s 2s/step - loss: 0.0441 - accuracy: 0.9831 - val_loss: 2.0818 - val_accuracy: 0.6413
# Epoch 8/35
# 200/200 [==============================] - 317s 2s/step - loss: 0.0543 - accuracy: 0.9797 - val_loss: 1.3950 - val_accuracy: 0.6913
# Epoch 9/35
# 200/200 [==============================] - 308s 2s/step - loss: 0.0269 - accuracy: 0.9916 - val_loss: 1.5880 - val_accuracy: 0.7550
# Epoch 10/35
# 200/200 [==============================] - 297s 1s/step - loss: 0.0343 - accuracy: 0.9872 - val_loss: 1.2293 - val_accuracy: 0.6925
# Epoch 11/35
# 200/200 [==============================] - 296s 1s/step - loss: 0.0239 - accuracy: 0.9897 - val_loss: 2.8383 - val_accuracy: 0.6100
# Epoch 12/35
# 200/200 [==============================] - 311s 2s/step - loss: 0.0341 - accuracy: 0.9875 - val_loss: 1.5706 - val_accuracy: 0.6837
# Epoch 13/35
# 200/200 [==============================] - 289s 1s/step - loss: 0.0143 - accuracy: 0.9941 - val_loss: 0.5575 - val_accuracy: 0.8675
# Epoch 14/35
# 200/200 [==============================] - 309s 2s/step - loss: 0.0247 - accuracy: 0.9919 - val_loss: 1.1272 - val_accuracy: 0.7425
# Epoch 15/35
# 200/200 [==============================] - 291s 1s/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.9732 - val_accuracy: 0.7788
# Epoch 16/35
# 200/200 [==============================] - 315s 2s/step - loss: 0.0158 - accuracy: 0.9934 - val_loss: 1.7999 - val_accuracy: 0.6787
# Epoch 17/35
# 200/200 [==============================] - 321s 2s/step - loss: 0.0095 - accuracy: 0.9962 - val_loss: 2.9218 - val_accuracy: 0.6875
# Epoch 18/35
# 200/200 [==============================] - 285s 1s/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 3.1309 - val_accuracy: 0.7138
# Epoch 19/35
# 200/200 [==============================] - 312s 2s/step - loss: 0.0162 - accuracy: 0.9944 - val_loss: 0.8423 - val_accuracy: 0.8238
# Epoch 20/35
# 200/200 [==============================] - 311s 2s/step - loss: 0.0235 - accuracy: 0.9919 - val_loss: 1.4784 - val_accuracy: 0.7475
# Epoch 21/35
# 200/200 [==============================] - 303s 2s/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 1.7272 - val_accuracy: 0.7775
# Epoch 22/35
# 200/200 [==============================] - 315s 2s/step - loss: 0.0299 - accuracy: 0.9922 - val_loss: 1.9830 - val_accuracy: 0.7113
# Epoch 23/35
# 200/200 [==============================] - 314s 2s/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 2.5423 - val_accuracy: 0.6750
# Epoch 24/35
# 200/200 [==============================] - 311s 2s/step - loss: 0.0278 - accuracy: 0.9909 - val_loss: 1.8652 - val_accuracy: 0.6888
# Epoch 25/35
# 200/200 [==============================] - 329s 2s/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 1.0473 - val_accuracy: 0.8612
# Epoch 26/35
# 200/200 [==============================] - 435s 2s/step - loss: 0.0095 - accuracy: 0.9959 - val_loss: 1.1156 - val_accuracy: 0.8087
# Epoch 27/35
# 200/200 [==============================] - 363s 2s/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 1.3812 - val_accuracy: 0.8313
# Epoch 28/35
# 200/200 [==============================] - 343s 2s/step - loss: 0.0271 - accuracy: 0.9919 - val_loss: 0.8200 - val_accuracy: 0.7925
# Epoch 29/35
# 200/200 [==============================] - 321s 2s/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 1.0415 - val_accuracy: 0.7900
# Epoch 30/35
# 200/200 [==============================] - 304s 2s/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 1.3016 - val_accuracy: 0.7812
# Epoch 31/35
# 200/200 [==============================] - 301s 2s/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 1.3500 - val_accuracy: 0.7975
# Epoch 32/35
# 200/200 [==============================] - 334s 2s/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 1.0980 - val_accuracy: 0.7800
# Epoch 33/35
# 200/200 [==============================] - 305s 2s/step - loss: 0.0036 - accuracy: 0.9981 - val_loss: 1.9813 - val_accuracy: 0.7713
# Epoch 34/35
# 200/200 [==============================] - 313s 2s/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 2.3858 - val_accuracy: 0.7437
# Epoch 35/35
# 200/200 [==============================] - 295s 1s/step - loss: 4.8995e-04 - accuracy: 1.0000 - val_loss: 1.9053 - val_accuracy: 0.7650
# Validating Folders:  ['p2', 'p7'] , ['p12', 'p17']
# Training Folders:  ['p1', 'p10', 'p3', 'p4', 'p5', 'p6', 'p8', 'p9'] , ['p11', 'p13', 'p14', 'p15', 'p16', 'p18', 'p19', 'p20']
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3200 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/35
# 200/200 [==============================] - 325s 2s/step - loss: 0.5695 - accuracy: 0.6853 - val_loss: 0.7699 - val_accuracy: 0.5000
# Epoch 2/35
# 200/200 [==============================] - 339s 2s/step - loss: 0.3812 - accuracy: 0.8244 - val_loss: 0.8274 - val_accuracy: 0.5487
# Epoch 3/35
# 200/200 [==============================] - 288s 1s/step - loss: 0.2326 - accuracy: 0.9031 - val_loss: 0.8299 - val_accuracy: 0.6888
# Epoch 4/35
# 200/200 [==============================] - 332s 2s/step - loss: 0.1477 - accuracy: 0.9394 - val_loss: 0.6597 - val_accuracy: 0.7850
step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 12.5953 - val_accuracy: 0.2763
# Epoch 14/35
# 200/200 [==============================] - 296s 1s/step - loss: 0.0275 - accuracy: 0.9900 - val_loss: 8.5963 - val_accuracy: 0.2525
# Epoch 15/35
# 200/200 [==============================] - 317s 2s/step - loss: 0.0163 - accuracy: 0.9956 - val_loss: 7.7868 - val_accuracy: 0.2900
# Epoch 16/35
# 200/200 [==============================] - 301s 2s/step - loss: 8.2547e-04 - accuracy: 1.0000 - val_loss: 11.6535 - val_accuracy: 0.2750
# Epoch 17/35
# 200/200 [==============================] - 281s 1s/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 12.2035 - val_accuracy: 0.2438
# Epoch 18/35
# 200/200 [==============================] - 302s 2s/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 12.8671 - val_accuracy: 0.2763
# Epoch 19/35
# 200/200 [==============================] - 323s 2s/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 15.0572 - val_accuracy: 0.2675
# Epoch 20/35
# 200/200 [==============================] - 304s 2s/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 11.4386 - val_accuracy: 0.2862
# Epoch 21/35
# 200/200 [==============================] - 312s 2s/step - loss: 0.0187 - accuracy: 0.9956 - val_loss: 11.7770 - val_accuracy: 0.2788
# Epoch 22/35
# 200/200 [==============================] - 274s 1s/step - loss: 7.4288e-04 - accuracy: 1.0000 - val_loss: 13.9881 - val_accuracy: 0.2512
# Epoch 23/35
# 200/200 [==============================] - 334s 2s/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 13.6716 - val_accuracy: 0.2512
# Epoch 24/35
# 200/200 [==============================] - 401s 2s/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 9.9603 - val_accuracy: 0.3137
# Epoch 25/35
# 200/200 [==============================] - 308s 2s/step - loss: 0.0104 - accuracy: 0.9975 - val_loss: 11.8285 - val_accuracy: 0.2812
# Epoch 26/35
# 200/200 [==============================] - 339s 2s/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 11.3704 - val_accuracy: 0.2788
# Epoch 27/35
# 200/200 [==============================] - 205s 1s/step - loss: 0.0204 - accuracy: 0.9931 - val_loss: 10.7450 - val_accuracy: 0.2800
# Epoch 28/35
# 200/200 [==============================] - 185s 924ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 13.4888 - val_accuracy: 0.2750
# Epoch 29/35
# 200/200 [==============================] - 176s 880ms/step - loss: 6.5315e-04 - accuracy: 1.0000 - val_loss: 14.8394 - val_accuracy: 0.2550
# Epoch 30/35
# 200/200 [==============================] - 160s 799ms/step - loss: 6.7883e-05 - accuracy: 1.0000 - val_loss: 15.3599 - val_accuracy: 0.2650
# Epoch 31/35
# 200/200 [==============================] - 136s 678ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 9.1527 - val_accuracy: 0.2850
# Epoch 32/35
# 200/200 [==============================] - 134s 672ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 13.4936 - val_accuracy: 0.2550
# Epoch 33/35
# 200/200 [==============================] - 143s 714ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 14.1150 - val_accuracy: 0.3137
# Epoch 34/35
# 200/200 [==============================] - 129s 646ms/step - loss: 0.0228 - accuracy: 0.9937 - val_loss: 8.0154 - val_accuracy: 0.3212
# Epoch 35/35
# 200/200 [==============================] - 131s 657ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 11.7961 - val_accuracy: 0.2512
# Validating Folders:  ['p4', 'p9'] , ['p14', 'p19']
# Training Folders:  ['p1', 'p10', 'p2', 'p3', 'p5', 'p6', 'p7', 'p8'] , ['p11', 'p12', 'p13', 'p15', 'p16', 'p17', 'p18', 'p20']
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3200 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1
ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 2.6954 - val_accuracy: 0.7150
# Epoch 35/35
# 200/200 [==============================] - 141s 707ms/step - loss: 0.0169 - accuracy: 0.9966 - val_loss: 0.8907 - val_accuracy: 0.8363

# %%
plot_all_acc(results)

# %% [markdown]
# Using 2 Patients in Validation Set for each class instead of just 1 to add more variation in accuracy test:

# %%
valid_label_size = 2 #number of patients from each label used in validation set
results = cross_validation(other_patients, covid_patients, valid_label_size)
# Out:
# Validating Folders:  ['p5', 'p7'] , ['p13', 'p17']
# Training Folders:  ['p1', 'p10', 'p2', 'p3', 'p4', 'p6', 'p8', 'p9'] , ['p11', 'p12', 'p14', 'p15', 'p16', 'p18', 'p19', 'p20']
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3200 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 200/200 [==============================] - 36s 182ms/step - loss: 0.5494 - accuracy: 0.7119 - val_loss: 0.5917 - val_accuracy: 0.7300
# Epoch 2/10
# 200/200 [==============================] - 36s 180ms/step - loss: 0.3734 - accuracy: 0.8250 - val_loss: 0.3776 - val_accuracy: 0.8388
# Epoch 3/10
# 200/200 [==============================] - 36s 179ms/step - loss: 0.2520 - accuracy: 0.8897 - val_loss: 0.8575 - val_accuracy: 0.7337
# Epoch 4/10
# 200/200 [==============================] - 35s 174ms/step - loss: 0.1703 - accuracy: 0.9331 - val_loss: 0.6484 - val_accuracy: 0.7887
# Epoch 5/10
# 200/200 [==============================] - 35s 176ms/step - loss: 0.1188 - accuracy: 0.9538 - val_loss: 0.5055 - val_accuracy: 0.8263
# Epoch 6/10
# 200/200 [==============================] - 35s 177ms/step - loss: 0.0779 - accuracy: 0.9716 - val_loss: 0.3685 - val_accuracy: 0.8625
# Epoch 7/10
# 200/200 [==============================] - 36s 179ms/step - loss: 0.0626 - accuracy: 0.9766 - val_loss: 0.8056 - val_accuracy: 0.8125
# Epoch 8/10
# 200/200 [==============================] - 37s 185ms/step - loss: 0.0475 - accuracy: 0.9828 - val_loss: 0.5080 - val_accuracy: 0.8438
# Epoch 9/10
# 200/200 [==============================] - 37s 186ms/step - loss: 0.0479 - accuracy: 0.9825 - val_loss: 0.7724 - val_accuracy: 0.8213
# Epoch 10/10
# 200/200 [==============================] - 38s 191ms/step - loss: 0.0400 - accuracy: 0.9872 - val_loss: 0.9021 - val_accuracy: 0.8087
# Validating Folders:  ['p6', 'p8'] , ['p11', 'p16']
# Training Folders:  ['p1', 'p10', 'p2', 'p3', 'p4', 'p5', 'p7', 'p9'] , ['p12', 'p13', 'p14', 'p15', 'p17', 'p18', 'p19', 'p20']
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3200 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 200/200 [==============================] - 39s 195ms/step - loss: 0.5342 - accuracy: 0.7125 - val_loss: 0.7993 - val_accuracy: 0.6050
# Epoch 2/10
# 200/200 [==============================] - 38s 192ms/step - loss: 0.3205 - accuracy: 0.8659 - val_loss: 1.7449 - val_accuracy: 0.6000
# Epoch 3/10
# 200/200 [==============================] - 39s 194ms/step - loss: 0.1819 - accuracy: 0.9250 - val_loss: 0.9000 - val_accuracy: 0.7000
# Epoch 4/10
# 200/200 [==============================] - 38s 191ms/step - loss: 0.1423 - accuracy: 0.9469 - val_loss: 2.0739 - val_accuracy: 0.6225
# Epoch 5/10
# 200/200 [==============================] - 38s 192ms/step - loss: 0.0814 - accuracy: 0.9672 - val_loss: 1.7349 - val_accuracy: 0.6700
# Epoch 6/10
# 200/200 [==============================] - 39s 193ms/step - loss: 0.0571 - accuracy: 0.9803 - val_loss: 3.9988 - val_accuracy: 0.6300
# Epoch 7/10
# 200/200 [==============================] - 39s 195ms/step - loss: 0.0579 - accuracy: 0.9825 - val_loss: 3.3256 - val_accuracy: 0.5063
# Epoch 8/10
# 200/200 [==============================] - 39s 195ms/step - loss: 0.0519 - accuracy: 0.9791 - val_loss: 2.6852 - val_accuracy: 0.6550
# Epoch 9/10
# 200/200 [==============================] - 38s 191ms/step - loss: 0.0517 - accuracy: 0.9784 - val_loss: 2.5078 - val_accuracy: 0.6662
# Epoch 10/10
# 200/200 [==============================] - 39s 193ms/step - loss: 0.0362 - accuracy: 0.9884 - val_loss: 1.9002 - val_accuracy: 0.6988
# Validating Folders:  ['p1', 'p4'] , ['p14', 'p15']
# Training Folders:  ['p10', 'p2', 'p3', 'p5', 'p6', 'p7', 'p8', 'p9'] , ['p11', 'p12', 'p13', 'p16', 'p17', 'p18', 'p19', 'p20']
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3200 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 200/200 [==============================] - 40s 202ms/step - loss: 0.5906 - accuracy: 0.6784 - val_loss: 0.6358 - val_accuracy: 0.7200
# Epoch 2/10
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4018 - accuracy: 0.8172 - val_loss: 0.6669 - val_accuracy: 0.7750
# Epoch 3/10
# 200/200 [==============================] - 39s 194ms/step - loss: 0.2491 - accuracy: 0.8950 - val_loss: 0.4256 - val_accuracy: 0.8025
# Epoch 4/10
# 200/200 [==============================] - 39s 195ms/step - loss: 0.1948 - accuracy: 0.9216 - val_loss: 0.4418 - val_accuracy: 0.8100
# Epoch 5/10
# 200/200 [==============================] - 39s 194ms/step - loss: 0.1496 - accuracy: 0.9444 - val_loss: 0.2852 - val_accuracy: 0.8612
# Epoch 6/10
# 200/200 [==============================] - 40s 202ms/step - loss: 0.0745 - accuracy: 0.9697 - val_loss: 0.4333 - val_accuracy: 0.8288
# Epoch 7/10
# 200/200 [==============================] - 39s 194ms/step - loss: 0.0832 - accuracy: 0.9712 - val_loss: 0.1585 - val_accuracy: 0.9375
# Epoch 8/10
# 200/200 [==============================] - 40s 200ms/step - loss: 0.0503 - accuracy: 0.9800 - val_loss: 0.4116 - val_accuracy: 0.8525
# Epoch 9/10
# 200/200 [==============================] - 40s 199ms/step - loss: 0.0503 - accuracy: 0.9816 - val_loss: 0.6721 - val_accuracy: 0.7937
# Epoch 10/10
# 200/200 [==============================] - 39s 195ms/step - loss: 0.0397 - accuracy: 0.9859 - val_loss: 0.6136 - val_accuracy: 0.8350
# Validating Folders:  ['p3', 'p9'] , ['p18', 'p19']
# Training Folders:  ['p1', 'p10', 'p2', 'p4', 'p5', 'p6', 'p7', 'p8'] , ['p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p20']
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3200 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 200/200 [==============================] - 40s 201ms/step - loss: 0.4381 - accuracy: 0.7922 - val_loss: 1.0357 - val_accuracy: 0.4913
# Epoch 2/10
# 200/200 [==============================] - 40s 199ms/step - loss: 0.1569 - accuracy: 0.9413 - val_loss: 2.4812 - val_accuracy: 0.3963
# Epoch 3/10
# 200/200 [==============================] - 40s 200ms/step - loss: 0.0719 - accuracy: 0.9722 - val_loss: 3.7784 - val_accuracy: 0.3787
# Epoch 4/10
# 200/200 [==============================] - 42s 210ms/step - loss: 0.0513 - accuracy: 0.9809 - val_loss: 3.3320 - val_accuracy: 0.3525
# Epoch 5/10
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0322 - accuracy: 0.9897 - val_loss: 3.4901 - val_accuracy: 0.4575
# Epoch 6/10
# 200/200 [==============================] - 42s 210ms/step - loss: 0.0276 - accuracy: 0.9894 - val_loss: 9.5994 - val_accuracy: 0.3462
# Epoch 7/10
# 200/200 [==============================] - 41s 206ms/step - loss: 0.0228 - accuracy: 0.9909 - val_loss: 5.8430 - val_accuracy: 0.3587
# Epoch 8/10
# 200/200 [==============================] - 40s 200ms/step - loss: 0.0178 - accuracy: 0.9947 - val_loss: 6.2525 - val_accuracy: 0.3562
# Epoch 9/10
# 200/200 [==============================] - 43s 216ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 8.8065 - val_accuracy: 0.3438
# Epoch 10/10
# 200/200 [==============================] - 42s 210ms/step - loss: 0.0331 - accuracy: 0.9891 - val_loss: 5.6644 - val_accuracy: 0.4075
# Validating Folders:  ['p10', 'p2'] , ['p12', 'p20']
# Training Folders:  ['p1', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9'] , ['p11', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19']
# Train fold with 3200 images
# label
# covid    1600
# other    1600
# Name: label, dtype: int64
#
# Validation fold with 800 images
# label
# covid    400
# other    400
# Name: label, dtype: int64
# ------------------------------
# Found 3200 validated image filenames belonging to 2 classes.
# Found 800 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 200/200 [==============================] - 41s 207ms/step - loss: 0.5805 - accuracy: 0.6809 - val_loss: 0.7056 - val_accuracy: 0.5625
# Epoch 2/10
# 200/200 [==============================] - 41s 205ms/step - loss: 0.3477 - accuracy: 0.8475 - val_loss: 0.9087 - val_accuracy: 0.5325
# Epoch 3/10
# 200/200 [==============================] - 41s 205ms/step - loss: 0.1982 - accuracy: 0.9162 - val_loss: 1.0459 - val_accuracy: 0.6575
# Epoch 4/10
# 200/200 [==============================] - 41s 203ms/step - loss: 0.0925 - accuracy: 0.9647 - val_loss: 1.4555 - val_accuracy: 0.6438
# Epoch 5/10
# 200/200 [==============================] - 41s 206ms/step - loss: 0.0936 - accuracy: 0.9644 - val_loss: 1.9587 - val_accuracy: 0.6438
# Epoch 6/10
# 200/200 [==============================] - 42s 208ms/step - loss: 0.0481 - accuracy: 0.9856 - val_loss: 1.5805 - val_accuracy: 0.6263
# Epoch 7/10
# 200/200 [==============================] - 42s 211ms/step - loss: 0.0506 - accuracy: 0.9803 - val_loss: 1.3506 - val_accuracy: 0.6225
# Epoch 8/10
# 200/200 [==============================] - 43s 213ms/step - loss: 0.0341 - accuracy: 0.9891 - val_loss: 2.3332 - val_accuracy: 0.5763
# Epoch 9/10
# 200/200 [==============================] - 42s 211ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 1.8376 - val_accuracy: 0.6112
# Epoch 10/10
# 200/200 [==============================] - 41s 204ms/step - loss: 0.0515 - accuracy: 0.9869 - val_loss: 1.5246 - val_accuracy: 0.7013

# %%
plot_all_acc(results)

# %% [markdown]
# Fitting or Loading a Final Model

# %%
#training a model that performed well in the cross validation to make predictions.
validation_folders_1 = sorted(normal_patients)[2:3] #we'll use p3 and p13 as the validation set
validation_folders_2 = sorted(covid_patients)[2:3] #using and interval so a list is returned
train_folders_1 = list(set(normal_patients) - set(validation_folders_1))
train_folders_2 = list(set(sorted(covid_patients)[0:5]) - set(validation_folders_2))
print("validating: ", validation_folders_1, validation_folders_2)
print("training: ", sorted(train_folders_1), sorted(train_folders_2))
train_set, validation_set = get_dicts(train_folders_1, train_folders_2, validation_folders_1, validation_folders_2)
train_df, validation_df = get_data(img_src_folder, train_set, img_src_folder, validation_set)
model = get_model()
history = train_model(model, train_df, validation_df, EPOCHS)
# Out:
# validating:  ['p3'] ['p13']
# training:  ['p1', 'p2', 'p4', 'p5'] ['p11', 'p12', 'p14', 'p15']
# Train fold with 1600 images
# label
# covid     800
# normal    800
# Name: label, dtype: int64
#
# Validation fold with 400 images
# label
# covid     200
# normal    200
# Name: label, dtype: int64
# ------------------------------
# Found 1600 validated image filenames belonging to 2 classes.
# Found 400 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 100/100 [==============================] - 19s 187ms/step - loss: 0.4901 - accuracy: 0.7469 - val_loss: 0.1967 - val_accuracy: 0.9625
# Epoch 2/10
# 100/100 [==============================] - 19s 188ms/step - loss: 0.2026 - accuracy: 0.9262 - val_loss: 0.0489 - val_accuracy: 0.9975
# Epoch 3/10
# 100/100 [==============================] - 19s 192ms/step - loss: 0.0905 - accuracy: 0.9700 - val_loss: 1.4351 - val_accuracy: 0.5925
# Epoch 4/10
# 100/100 [==============================] - 18s 184ms/step - loss: 0.0648 - accuracy: 0.9775 - val_loss: 0.5479 - val_accuracy: 0.7875
# Epoch 5/10
# 100/100 [==============================] - 18s 184ms/step - loss: 0.0562 - accuracy: 0.9794 - val_loss: 0.2352 - val_accuracy: 0.9025
# Epoch 6/10
# 100/100 [==============================] - 18s 184ms/step - loss: 0.0616 - accuracy: 0.9787 - val_loss: 0.6564 - val_accuracy: 0.7200
# Epoch 7/10
# 100/100 [==============================] - 18s 185ms/step - loss: 0.0511 - accuracy: 0.9831 - val_loss: 1.0616 - val_accuracy: 0.6625
# Epoch 8/10
# 100/100 [==============================] - 19s 185ms/step - loss: 0.0195 - accuracy: 0.9925 - val_loss: 1.3298 - val_accuracy: 0.6250
# Epoch 9/10
# 100/100 [==============================] - 19s 192ms/step - loss: 0.1214 - accuracy: 0.9581 - val_loss: 0.1108 - val_accuracy: 0.9625
# Epoch 10/10
# 100/100 [==============================] - 19s 186ms/step - loss: 0.0903 - accuracy: 0.9681 - val_loss: 1.5143 - val_accuracy: 0.6500

# %%
#saving the final model
model.save('model.h5')

# %%
if os.path.isfile('model.h5'):
    from keras.models import load_model
    model = load_model('model.h5')
    model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 5, 5, 128)         147584
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 651,585
# Trainable params: 651,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Making Predictions to Patients in Test Set

# %%
test_patients = sorted(TEST_IMG_FOLDERS) 
test_patients
# Out:
# ['p16', 'p17', 'p18', 'p19', 'p20']

# %%
if len(test_patients)>0:
    batch_size = 16
    width = 150
    height = 150
    results = []
    for p in test_patients:
        curr_dir = img_src_folder + '/' + p + '/segmented/' 
        test_filenames = os.listdir(curr_dir)
        test_df = pd.DataFrame({
                'filename': test_filenames
         })
        nb_samples = test_df.shape[0]

        test_gen = ImageDataGenerator(rescale=1./255)
        test_generator = test_gen.flow_from_dataframe(
                test_df, 
                curr_dir, 
                x_col='filename',
                y_col=None,
                class_mode=None,
                target_size=(width, height),
                batch_size=batch_size,
                shuffle=False
        )

        predict = model.predict(test_generator, steps=np.ceil(nb_samples/batch_size))
        test_df['category'] = [int(round(p[0])) for p in predict]
        results.append(test_df)
# Out:
# Found 431 validated image filenames.
# Found 1058 validated image filenames.
# Found 468 validated image filenames.
# Found 489 validated image filenames.
# Found 538 validated image filenames.

# %% [markdown]
# Visualizing General Predictions

# %%
for i,test_df in enumerate(results):
    print('Patient number: ', i+1)
    if os.path.isfile('label_legend.npy'):
        class_indices = np.load('label_legend.npy', allow_pickle=True).item()
        class_indices = dict((v,k) for k,v in class_indices.items())
        test_df['category'] = test_df['category'].replace(class_indices)
    print(test_df['category'].value_counts())
    print('')
# Out:
# Patient number:  1
# covid     312
# normal    119
# Name: category, dtype: int64
#
# Patient number:  2
# covid     877
# normal    181
# Name: category, dtype: int64
#
# Patient number:  3
# normal    319
# covid     149
# Name: category, dtype: int64
#
# Patient number:  4
# covid     394
# normal     95
# Name: category, dtype: int64
#
# Patient number:  5
# covid     330
# normal    208
# Name: category, dtype: int64
