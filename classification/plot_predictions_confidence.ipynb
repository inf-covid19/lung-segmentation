# %% [markdown]
# predictions file example:

# %%
predictions_file
# Out:
#     Unnamed: 0  predictions
# 0            0          1.0
# 1            1          1.0
# 2            2          1.0
# 3            3          1.0
# 4            4          1.0
# ..         ...          ...
# 95          95          1.0
# 96          96          1.0
# 97          97          1.0
# 98          98          1.0
# 99          99          1.0
#
# [100 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
def plot_patient_preds(p_csv_filename, p_name):
    predictions_file = pd.read_excel('../../../../cidia_scripts/' + p_csv_filename)
    y_axis = predictions_file["predictions"]
    x_axis = np.linspace(0,100,100)
    plt.plot(x_axis, y_axis, 'bo', label='', scaley = False)
    plt.title('Grau de Confianca por fatia do paciente ' + p_name)
    plt.show()

# %%
plot_patient_preds('preds_p007.xlsx', 'NEG-007')

# %%
plot_patient_preds('preds_pC24.xlsx', 'C24')

# %%
plot_patient_preds('preds_pC140.xlsx', 'C140')

# %%
plot_patient_preds('preds_p028.xlsx', 'IND-028')

# %%
plot_patient_preds('preds.xlsx', 'C33')

# %%
plot_patient_preds('preds_p007.xlsx', 'TYP-007')

# %%
plot_patient_preds('preds_pC161.xlsx', 'C161')

# %%
plot_patient_preds('preds_pC82.xlsx', 'C82')
